# %%
import xml.etree.ElementTree as ET
import pandas as pd 
import os 
from collections import Counter
import plotly.figure_factory as ff
import numpy as np
import plotly.express as px

# %% [markdown]
# ### Read xmls files

# %%
xml_dir = "labeld_images_and_xml"
xmls_names = [f for f in os.listdir(xml_dir) if "xml" in f]

# %% [markdown]
# ### Count lables in each file

# %%
d = []
for f in xmls_names:
    path = os.path.join(xml_dir,f)
    mytree = ET.parse(path)
    myroot = mytree.getroot()
    dict_file = Counter([a.text for a in  myroot.iter('name')])
    dict_file["file"]  = f
    d.append(dict_file)

# %% [markdown]
# ## Isoating numeric columns

# %%
df = pd.DataFrame.from_dict(d)
group_labels = [col for col,typ in zip(df.columns, df.dtypes) if typ == "float64"]
group_labels
# Out:
# ['freeFS',
#  'drinking',
#  'eating_24',
#  'freeDC',
#  'freeD',
#  'freeFSN',
#  'eating_g',
#  'mushroom',
#  'drinking_g',
#  'drinking_b',
#  'eating_l',
#  'grouped']

# %% [markdown]
# ## Labeling errors check

# %%
# Check for labeling mistakes 
df.columns
# Out:
# Index(['freeFS', 'file', 'drinking', 'eating_24', 'freeDC', 'freeD', 'freeFSN',
#        'eating_g', 'mushroom', 'drinking_g', 'drinking_b', 'eating_l',
#        'grouped'],
#       dtype='object')

# %%
# Mapping istakes to correct lables 
error_map = { 
             
             'eating_e':"eating_s",
             'freeDc':"freeDC",
             "eating_2s":"eating_s",
             "\\":"freeDC",
             "EA":"eating_s",
             "eating":"drinking",
             """eating_g\\""": "eating_g",
            "eating_d":"eating",
            "eating_s":"eating",
            "eating_b":"eating",
            "eating_2":"eating_24",
             "freeC":"freeD",
             "eating_sw":"eating",
            "gruoped":"grouped",
            "eating_on":"eating_in",
           "mushtoom":"mushroom"

}

# %%
# Find files with mistakes 
errors_dict = {}
for col in error_map.keys():
    if col in df.columns:
        errors_dict[col] = df[~df[col].isnull()]["file"].tolist()
    else:
        print(f"""error of type -- '{col}' -- not exist any more\n""")
        
error_map = {k:v for k,v in error_map.items() if k in errors_dict}
print(f"""'error_map get' updated to {error_map}\n""")
print(f"The following files contain lables mistakes {errors_dict}")
# Out:
# error of type -- 'eating_e' -- not exist any more
#
# error of type -- 'freeDc' -- not exist any more
#
# error of type -- 'eating_2s' -- not exist any more
#
# error of type -- '\' -- not exist any more
#
# error of type -- 'EA' -- not exist any more
#
# error of type -- 'eating' -- not exist any more
#
# error of type -- 'eating_g\' -- not exist any more
#
# error of type -- 'eating_d' -- not exist any more
#
# error of type -- 'eating_s' -- not exist any more
#
# error of type -- 'eating_b' -- not exist any more
#
# error of type -- 'eating_2' -- not exist any more
#
# error of type -- 'freeC' -- not exist any more
#
# error of type -- 'eating_sw' -- not exist any more
#
# error of type -- 'gruoped' -- not exist any more
#
# error of type -- 'eating_on' -- not exist any more
#
# error of type -- 'mushtoom' -- not exist any more
#
# 'error_map get' updated to {}
#
# The following files contain lables mistakes {}

# %%
# Iterate throw files, mapping error to correct values, save files back 
for error,fix in error_map.items():
    files = errors_dict[error]
    for f in files:
        path = os.path.join(xml_dir,f)
        mytree = ET.parse(path)
        myroot = mytree.getroot()
        
        for name in myroot.iter('name'):
            if name.text == error:
                print(name.text)
                name.text = fix
        mytree.write(file_or_filename=path)

# %%
for f in xmls_names:
    path = os.path.join(xml_dir,f)
    with open(path) as f:
        lines = f.read()
    c = 0
    for i in group_labels:
        if i in lines:
            c +=1

    if c == 0:
        print(path)
    if "test" in path:
        print(path)
        break

# %%
path
# Out:
# 'labeld_images_and_xml/time=20220520T075000Z_growing_day=11_camera=201.xml'

# %% [markdown]
# # Distribution plot

# %%
import plotly.graph_objects as go

fig = go.Figure()

for i in group_labels:
    fig.add_trace(go.Histogram(x=df[i],name=i))

# Overlay both histograms
fig.update_layout(barmode='overlay')
# Reduce opacity to see both histograms
fig.update_traces(opacity=0
,null,null,3.0,21.0,null,14.0,21.0,null,null,1.0,null,null,20.0,null,null,null,null,null,null,5.0,8.0,21.0,null,9.0,null,null,15.0,27.0,null,6.0,null,4.0,24.0,1.0,5.0,null,2.0,null,null,7.0,23.0,null,21.0,null,null,null,1.0,null,13.0,null,8.0,null,null,null,null,9.0,13.0],"type":"histogram","opacity":0.6},{"name":"freeFSN","x":[null,null,5.0,5.0,null,null,null,5.0,null,null,null,null,null,null,null,5.0,null,5.0,null,5.0,null,5.0,null,null,null,null,5.0,null,null,5.0,5.0,null,null,null,5.0,null,null,null,null,null,null,5.0,5.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,5.0,null,null,null,5.0,null,null,null,null,null,null,5.0,5.0,5.0,null,null,null,null,null,null,null,null,null,null,5.0,null,null,null,null,null,null,null,null,5.0,null,null,null,null,null,5.0,5.0,null,null,5.0,null,null,null,null,null,5.0,null,null,null],"type":"hi ...

# %% [markdown]
# ### Pie plot

# %%
cols = df.columns

# %%
df.head()
# Out:
#    freeFS                                               file  drinking  \
# 0     7.0  time=20220521T202200Z_growing_day=12_camera=20...       NaN
# 1     1.0  time=20220520T153000Z_growing_day=11_camera=20...       7.0
# 2     NaN  time=20220524T030200Z_growing_day=15_camera=30...       NaN
# 3     NaN  time=20220520T000000Z_growing_day=11_camera=20...       NaN
# 4     NaN  time=20220520T105000Z_growing_day=11_camera=20...       6.0
#
#    eating_24  freeDC  freeD  freeFSN  eating_g  mushroom  drinking_g  \
# 0        NaN     NaN    NaN      NaN       NaN       NaN         NaN
# 1        3.0    14.0   23.0      NaN       NaN       NaN         NaN
# 2        NaN     NaN    NaN      5.0       NaN       NaN         NaN
# 3        NaN     NaN    NaN      5.0       NaN       NaN         NaN
# 4        NaN     5.0   20.0      NaN       3.0       4.0         3.0
#
#    drinking_b  eating_l  grouped
# 0         NaN       NaN      NaN
# 1         NaN       NaN      NaN
# 2         NaN       NaN      NaN
# 3         NaN       NaN      NaN
# 4         1.0       NaN      NaN

# %%
dd = df.melt(
        value_vars = cols)

# %%
fig = px.pie(dd, values='value', names='variable', title='Labels proportion')
fig.show()
# Out:
# <div>                            <div id="2c5f8491-8d38-403c-a96c-f4b59cab9095" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c5f8491-8d38-403c-a96c-f4b59cab9095")) {                    Plotly.newPlot(                        "2c5f8491-8d38-403c-a96c-f4b59cab9095",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"variable=%{label}<br>value=%{value}<extra></extra>","labels":["freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","freeFS","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","file","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","drinking","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","eating_24","e ...

# %%
def copy_xml_paths_names(input_folder: str,
                         output_folder: str,
                         file_name: str,
                         typ: str
                         ):

    # reading xml
    xml_input_path = f"{input_folder}/{file_name}.xml"
    xml_output_path = f"{output_folder}/{file_name}.xml"
    mytree = ET.parse(xml_input_path)
    myroot = mytree.getroot()

    for folder in myroot.iter('folder'):
        folder.text = input_folder

    for filename in myroot.iter('filename'):
        file_name = f"{file_name}.{typ}"
        filename.text = file_name

    for path in myroot.iter('path'):
        wd = os.getcwd()
        path_name = os.path.join(wd, input_folder, file_name)
        path.text = path_name

    if not os.path.exists(output_folder):
        os.makedirs(name=output_folder)

    mytree.write(file_or_filename=xml_output_path)

# %%
import os 
from PIL import Image

c = 0 
d = "augmented_images_and_xml"
la = os.listdir(d)

d = "augmented_images_and_xml"
lb = os.listdir(d)

for i in la[:]:
    if ("301.xml" in i ) or ("201.xml" in i ):
        os.remove(f"{d}/{i}")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hz/jw69d7s516q7_yst5pxmtr3c0000gn/T/ipykernel_89759/2828686763.py in <module>
# ----> 1 os.remove()
#
# TypeError: remove() missing required argument 'path' (pos 1)
