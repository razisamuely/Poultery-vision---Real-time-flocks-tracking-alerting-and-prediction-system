# %% [markdown]
# # 1. Import Dependencies

# %%
from image_collection import imageLabel

# %%
il = imageLabel()

# %% [markdown]
# # Get configs

# %%
configs = il.get_label_image_confs()
configs.__dict__.keys()
# Out:
# dict_keys(['LABEL_IMAGE_COMMANDES', 'IMAGE_PATH', 'LABELIMG_PATH', 'labels'])

# %% [markdown]
# # Installations

# %%
il.installations(configs.LABEL_IMAGE_COMMANDES, configs.LABELIMG_PATH)

# %% [markdown]
# # 3. Setup Folders

# %%
il.set_folders(image_path = configs.IMAGE_PATH,
               labels = configs.labels,
               lablimg_path = configs.LABELIMG_PATH )

# %% [markdown]
# # 5. Image Labelling

# %%
il.open_labelimg(path = configs.LABELIMG_PATH)
# Out:
# /Users/raz.shmuely/Documents/privet/chickens/chicken_classification_project/TFODCourse/Tensorflow/labelimg/labelImg.py:965: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   bar.setValue(bar.value() + bar.singleStep() * units)
# qt.qpa.window: Window position QRect(1649,-1272 100x30) outside any known screen, using primary screen
# qt.qpa.window: Window position QRect(1273,-1272 100x30) outside any known screen, using primary screen
# qt.qpa.window: Window position QRect(1284,-1272 100x30) outside any known screen, using primary screen
# qt.qpa.window: Window position QRect(1342,-1272 100x30) outside any known screen, using primary screen
# qt.qpa.window: Window position QRect(1397,-1272 100x30) outside any known screen, using primary screen
# qt.qpa.window: Window position QRect(1043,-1272 100x30) outside any known screen, using primary screen
# ...

# %% [markdown]
# # 6. Move images  into a Training and Testing Partition

# %% [markdown]
# ## * Optional - 7. Compress images for Colab Training

# %%
il.compress_images()
